# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/dataset/bank .csv")

# %% [markdown]
# Identify columns with dtypes = object

# %%
object = df.select_dtypes(include='object').columns
print(object)#provide column name
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# Unique values of those columns

# %%
for col in object:
    unique_values = df[col].unique()
    print(f"Unique values in column '{col}':")
    print(unique_values)
    print()
# Out:
# Unique values in column 'job':
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
# Unique values in column 'marital':
# ['married' 'single' 'divorced']
#
# Unique values in column 'education':
# ['tertiary' 'secondary' 'unknown' 'primary']
#
# Unique values in column 'default':
# ['no' 'yes']
#
# Unique values in column 'housing':
# ['yes' 'no']
#
# Unique values in column 'loan':
# ['no' 'yes']
#
# Unique values in column 'contact':
# ['unknown' 'cellular' 'telephone']
#
# Unique values in column 'month':
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
# Unique values in column 'poutcome':
# ['unknown' 'failure' 'other' 'success']
#
# Unique values in column 'y':
# ['no' 'yes']

# %% [markdown]
# Check for the total number of null values in each column

# %%
null_values = df.isnull().sum()
print(null_values)
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# Drop all the columns with dtypes object and store in new DataFrame, also write the DataFrame in ".csv" with name "banknumbericdata.csv"

# %%
numeric_df = df.drop(columns = object)
numeric_df.to_csv("banknumericdata.csv", index = False)

numeric_data = pd.read_csv("banknumericdata.csv")
summary = numeric_data.describe()
print(summary)
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...
